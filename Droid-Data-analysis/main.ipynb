# %%
"""
# !gsutil ls gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2023-09-21/Thu_Sep_21_17:26:41_2023

"relative_path": "AUTOLab/failure/2023-07-07/Fri_Jul__7_10:00:27_2023",
        
"""

# !gsutil ls gs://gresearch/robotics/droid_raw/1.0.1/AUTOLab/failure/2023-07-07/Fri_Jul__7_10:00:27_2023
# Out:
# /home/aniruth/miniconda3/envs/sim_cam/lib/python3.7/site-packages/OpenSSL/SSL.py:15: CryptographyDeprecationWarning: Python 3.7 is no longer supported by the Python core team and support for it is deprecated in cryptography. The next release of cryptography will remove support for Python 3.7.
#   from cryptography import x509
# gs://gresearch/robotics/droid_raw/1.0.1/AUTOLab/failure/2023-07-07/Fri_Jul__7_10:00:27_2023/metadata_AUTOLab+5d05c5aa+2023-07-07-10h-00m-27s.json
# gs://gresearch/robotics/droid_raw/1.0.1/AUTOLab/failure/2023-07-07/Fri_Jul__7_10:00:27_2023/trajectory.h5
# gs://gresearch/robotics/droid_raw/1.0.1/AUTOLab/failure/2023-07-07/Fri_Jul__7_10:00:27_2023/recordings/

# %%
# !gsutil ls gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2023-09-21/Thu_Sep_21_17:26:41_2023/recordings/SVO
# Out:
# /home/aniruth/miniconda3/envs/sim_cam/lib/python3.7/site-packages/OpenSSL/SSL.py:15: CryptographyDeprecationWarning: Python 3.7 is no longer supported by the Python core team and support for it is deprecated in cryptography. The next release of cryptography will remove support for Python 3.7.
#   from cryptography import x509
# gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2023-09-21/Thu_Sep_21_17:26:41_2023/recordings/SVO/14549178.svo
# gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2023-09-21/Thu_Sep_21_17:26:41_2023/recordings/SVO/20252535.svo
# gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2023-09-21/Thu_Sep_21_17:26:41_2023/recordings/SVO/25947356.svo

# %%
# Step 1: Create the directory (only if it doesn’t exist)
# !mkdir -p svo

# Step 2: Copy all .svo files into that directory
# !gsutil cp gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2024-01-10/Wed_Jan_10_16:02:56_2024/recordings/SVO/*.svo svo/
# Out:
# /home/aniruth/miniconda3/envs/sim_cam/lib/python3.7/site-packages/OpenSSL/SSL.py:15: CryptographyDeprecationWarning: Python 3.7 is no longer supported by the Python core team and support for it is deprecated in cryptography. The next release of cryptography will remove support for Python 3.7.
#   from cryptography import x509
# Copying gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2024-01-10/Wed_Jan_10_16:02:56_2024/recordings/SVO/19553404.svo...
# Copying gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2024-01-10/Wed_Jan_10_16:02:56_2024/recordings/SVO/28451778.svo...
# Copying gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2024-01-10/Wed_Jan_10_16:02:56_2024/recordings/SVO/28813166.svo...
# \ [3 files][ 32.9 MiB/ 32.9 MiB]
# Operation completed over 3 objects/32.9 MiB.
