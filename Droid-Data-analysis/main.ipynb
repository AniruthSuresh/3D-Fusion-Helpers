# %%
pip install gsutil
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 5.8 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached fasteners-0.20-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
# Using cached fasteners-0.20-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 5.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.8 MB/s eta 0:00:006.0 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 5.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#   Created wheel for gsutil: filename=gsutil-5.35-py3-none-any.whl size=3791063 sha256=e8aa07233a762bb52083a674ae2a6a81333b88fec8f9c9be19e7305f22165dee
#   Stored in directory: /home/aniruth/.cache/pip/wheels/91/26/5f/5880fbaf04a5831d18e81ba7c953d7dbc7f71e49f9245ae598
# ...

# %%
"""
# !gsutil ls gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2023-09-21/Thu_Sep_21_17:26:41_2023

"relative_path": "AUTOLab/failure/2023-07-07/Fri_Jul__7_10:00:27_2023",
        
"""

# !gsutil ls gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2024-01-10/Wed_Jan_10_16:02:56_2024/recordings/
# Out:
# gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2024-01-10/Wed_Jan_10_16:02:56_2024/recordings/MP4/
# gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2024-01-10/Wed_Jan_10_16:02:56_2024/recordings/SVO/

# %%
# !gsutil cp gs://gresearch/robotics/droid_raw/1.0.1/AUTOLab/failure/2023-07-07/Fri_Jul__7_10:00:27_2023/trajectory.h5 .
# Out:
# Copying gs://gresearch/robotics/droid_raw/1.0.1/AUTOLab/failure/2023-07-07/Fri_Jul__7_10:00:27_2023/trajectory.h5...
# \ [1 files][  2.6 MiB/  2.6 MiB]
# Operation completed over 1 objects/2.6 MiB.

# %%
# !gsutil ls gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2023-09-21/Thu_Sep_21_17:26:41_2023/
# Out:
# /bin/bash: line 1: gsutil: command not found

# %%
# Step 1: Create the directory (only if it doesn’t exist)
# !mkdir -p svo

# Step 2: Copy all .svo files into that directory
# !gsutil cp gs://gresearch/robotics/droid_raw/1.0.1/TRI/success/2024-01-10/Wed_Jan_10_16:02:56_2024/recordings/SVO/*.svo svo/
# Out:
# /bin/bash: line 1: gsutil: command not found
